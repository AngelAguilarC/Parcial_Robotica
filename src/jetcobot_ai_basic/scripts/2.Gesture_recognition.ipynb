# %% [markdown]
# <center><img src="./logo.png" alt="Header" style="width: 800px;"/></center>

# %% [markdown]
# # 定义手势识别函数部分

# %%
#导入相关的模块 Import related modules
import threading
import cv2 
import time
import math
from time import sleep
import ipywidgets.widgets as widgets
from gesture_action import handDetector
from jetcobot_utils.grasp_controller import GraspController
import time

# %%
graspController = GraspController()
# 初始化机械臂位姿 Initialize the robot arm pose
graspController.init_pose()

# %%
g_camera = cv2.VideoCapture(0)
g_camera.set(3, 640)
g_camera.set(4, 480)
g_camera.set(5, 30)  #设置帧率 Set the frame rate
g_camera.set(cv2.CAP_PROP_FOURCC, cv2.VideoWriter.fourcc('M', 'J', 'P', 'G'))
g_camera.set(cv2.CAP_PROP_BRIGHTNESS, 40) #设置亮度 -64 - 64  0.0 Set brightness -64 - 64 0.0
g_camera.set(cv2.CAP_PROP_CONTRAST, 50) #设置对比度 -64 - 64  2.0 Set Contrast -64 - 64 2.0
g_camera.set(cv2.CAP_PROP_EXPOSURE, 156) #设置曝光值 1.0 - 5000  156.0 Set the exposure value 1.0 - 5000 156.0
# Out:
# [ WARN:0@12.143] global cap_gstreamer.cpp:1777 open OpenCV | GStreamer warning: Cannot query video position: status=0, value=-1, duration=-1
# [ WARN:0@16.049] global cap_gstreamer.cpp:2152 setProperty OpenCV | GStreamer warning: GStreamer: unhandled property
# [ WARN:0@16.068] global cap_gstreamer.cpp:2152 setProperty OpenCV | GStreamer warning: GStreamer: unhandled property
# False

# %%
hand_detector = handDetector(detectorCon=0.75)
image_original = widgets.Image(format='jpeg', width=640, height=480)
image_result = widgets.Image(format='jpeg', width=640, height=480)
image_widget = widgets.HBox([image_original, image_result])
# Out:
# Error in cpuinfo: prctl(PR_SVE_GET_VL) failed
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
#bgr8转jpeg格式 bgr8 to jpeg format
def bgr8_to_jpeg(value, quality=75):
    return bytes(cv2.imencode('.jpg', value)[1])

# %% [markdown]
# # 定义摄像头显示组件

# %% [markdown]
# # 主进程

# %%
display(image_widget)
m_fps = 0
t_start = time.time()
try:
    while True:
        ret, frame = g_camera.read()
        frame, img = hand_detector.findHands(frame, draw=False)
        if len(hand_detector.lmList) != 0:
            finger_number = hand_detector.get_gesture()
            cv2.rectangle(frame, (0, 430), (230, 480), (0, 255, 0), cv2.FILLED)
            cv2.putText(frame, str(finger_number), (10, 470), cv2.FONT_HERSHEY_PLAIN, 2, (255, 0, 0), 2)
            print("Number:", finger_number)
        
        m_fps = m_fps + 1
        fps = m_fps / (time.time() - t_start)
        if (time.time() - t_start) >= 2:
            m_fps = fps
            t_start = time.time() - 1
        text="FPS:" + str(int(fps))
        cv2.putText(frame, text, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)
        image_original.value = bgr8_to_jpeg(frame)
        image_result.value = bgr8_to_jpeg(img)
except:
    print(" Program closed! ")
    pass
# Out:
# HBox(children=(Image(value=b'', format='jpeg', height='480', width='640'), Image(value=b'', format='jpeg', hei…
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1746687559.693284  890777 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746687559.760204  890777 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1746687574.778661  890781 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# Number: One
# Number: Four
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: One
# Number: Two
# Number: Two
# Number: Two
# Number: Two
# Number: Two
# Number: Two
# Number: Two
# Number: Two
# Number: Two
# Number: Two
# Number: Two
# Number: Two
# Number: Two
# Number: Three
# Number: Three
# Number: Three
# Number: Three
# Number: Three
# Number: Three
# Number: Three
# Number: Three
# Number: Three
# Number: Three
# Number: Three
# Number: Three
# Number: Three
# Number: Four
# Number: Four
# Number: Four
# Number: Four
# Number: Three
# Number: Four
# Number: Four
# Number: Four
# Number: Four
# Number: Four
# Number: Four
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Four
# Number: Four
# Number: Four
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Five
# Number: Six
# Number: Six
# Number: Six
# Number: Six
# Number: Six
# Number: Six
# Number: Six
# Number: Six
# Number: Six
# Number: Six
# Number: Six
# Number: One
# Number: Zero
# Number: Zero
# Number: One
# Number: Zero
# Number: Zero
# Number: Zero
# Number: One
# Number: Zero
# Number: Zero
# Number: Zero
# Number: One
# Number: Eight
# Number: Eight
# Number: Eight
# Number: Eight
# Number: Eight
# Number: Eight
# Number: Eight
# Number: Eight
# Number: Eight
# Number: Eight
# Number: Eight
# Number: Eight
# Number: Two
#  Program closed!

# %%
g_camera.release()              #使用完成对象记住释放掉对象，不然下一个程序使用这个对象模块会被占用，导致无法使用 After using the object, remember to release the object, otherwise the object module will be occupied by the next program, making it unusable
